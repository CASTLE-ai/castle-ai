# %%
import torch

# %%
model = torch.hub.load('facebookresearch/dinov2', 'dinov2_vitb14_reg')
# Out:
# Using cache found in /home/raiso/.cache/torch/hub/facebookresearch_dinov2_main
# /home/raiso/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /home/raiso/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# /home/raiso/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:33: UserWarning: xFormers is available (Block)
#   warnings.warn("xFormers is available (Block)")

# %%
model.patch_embed.patches_resolution
# Out:
# (37, 37)
